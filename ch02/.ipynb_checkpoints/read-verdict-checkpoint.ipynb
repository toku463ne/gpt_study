# %%
import sys, os

with open("edith-wharton.txt", "r") as f:
    text = f.read()

print("Total number of character:", len(text))
print(text[:99])
# Out:
# Total number of character: 20480
# HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no gr
